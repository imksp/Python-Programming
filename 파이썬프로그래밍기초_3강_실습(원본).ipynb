# %% [markdown]
# <a href="https://colab.research.google.com/github/imksp/Python-Programming/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_3%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3강 파이썬의 이해 - 실습

# %% [markdown]
# ## 3강 1절 - 데이터 타입과 변수

# %%
53000000
# Out:
# 53000000

# %%
print("Hello World")
print("Python is fun!")
# Out:
# Hello World
# Python is fun!

# %%
1 / 3 * 3.14 * 10 * 10 * 24
# Out:
# 2512.0

# %%
3.14 * 10 * 10 + 3.14 * 10 * 26
# Out:
# 1130.4

# %% [markdown]
# ## 3강 2절 - 연산자

# %%
2 ** 10
# Out:
# 1024

# %%
5 / 2 # 분수
# Out:
# 2.5

# %%
5 // 2 #정수 나눗셈에서 몫
# Out:
# 2

# %%
25 % 7 # 정수 나눗셈에서 나머지
# Out:
# 4

# %%
8.4 % 0.9
# Out:
# 0.30000000000000016

# %%
number = 19
number % 2
# Out:
# 1

# %%
max(2, 3, 4)
# Out:
# 4

# %%
min(2, 3, 4)
# Out:
# 2

# %%
round(3.141592, 2)
# Out:
# 3.14

# %%
round(3.415)
# Out:
# 3

# %%
abs(-3)
# Out:
# 3

# %%
pow(2, 3)
# Out:
# 8

# %% [markdown]
# ## 3강 3절 - 파이썬 기초문법 상식

# %%
print((4.5 * 2 + 4.0 * 3) / (130 - 66))
# Out:
# 0.328125
